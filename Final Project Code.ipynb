# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
spy_df = pd.read_csv("SPY 2001-2021.csv")
spy_df.head()
# Out:
#    id    Date       Open       High        Low       Close  Adj Close  \
# 0   1  1/2/01  132.00000  132.15625  127.56250  128.812500  85.693497
# 1   2  1/3/01  128.31250  136.00000  127.65625  135.000000  89.809753
# 2   3  1/4/01  134.93750  135.46875  133.00000  133.546875  88.843063
# 3   4  1/5/01  133.46875  133.62500  129.18750  129.187500  85.942963
# 4   5  1/8/01  129.87500  130.18750  127.68750  130.187500  86.608238
#
#      Volume
# 0   8737500
# 1  19431600
# 2   9219000
# 3  12911400
# 4   6625300

# %%
vde_df = pd.read_csv("VDE 2004-2010.csv")
vde_df.head()
# Out:
#    id     Date       Open       High        Low      Close  Adj Close  Volume
# 0   1  9/30/04  50.439999  50.439999  50.250000  50.419998  33.725319    4500
# 1   2  10/1/04  50.450001  51.090000  50.450001  51.070000  34.160099    6700
# 2   3  10/4/04  51.099998  51.240002  51.009998  51.119999  34.193542    6800
# 3   4  10/5/04  51.509998  51.750000  51.509998  51.590000  34.507908    8600
# 4   5  10/6/04  52.020000  52.580002  51.980000  52.580002  35.170109   14400

# %%
vde_df = pd.read_csv("VDE 2011-2021.csv")
vde_df.head()
# Out:
#    id    Date        Open        High         Low       Close  Adj Close  \
# 0   1  1/3/11  100.800003  101.209999  100.430000  100.599998  72.686493
# 1   2  1/4/11  101.300003  101.300003   98.849998   99.839996  72.137367
# 2   3  1/5/11   99.480003  100.290001   98.940002  100.180000  72.383011
# 3   4  1/6/11  100.550003  100.610001   98.959999   99.379997  71.804985
# 4   5  1/7/11   99.389999  100.320000   99.050003  100.000000  72.252991
#
#    Volume
# 0  269200
# 1  259700
# 2  197800
# 3  184000
# 4  218800

# %%
vht_df = pd.read_csv("VHT 2004-2021.csv")
vht_df.head()
# Out:
#    id    Date       Open       High        Low      Close  Adj Close  Volume
# 0   1  2/2/04  50.099998  50.799999  49.980000  50.570000  39.391872    8700
# 1   2  2/3/04  50.549999  50.889999  50.500000  50.889999  39.641136    7300
# 2   3  2/4/04  50.779999  51.119999  50.759998  50.930000  39.672283    8600
# 3   4  2/5/04  50.930000  50.930000  50.450001  50.660000  39.461983   16300
# 4   5  2/6/04  50.669998  51.009998  50.500000  50.980000  39.711258    6800

# %%
spy_df.dtypes
# Out:
# id             int64
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
vde_df.dtypes
# Out:
# id             int64
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
vht_df.dtypes
# Out:
# id             int64
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
vht_df = vht_df.loc[:,["Date","Open","Close"]]

# %%
df2 = vht_df.reset_index(drop=True)
df2
# Out:
#           Date        Open       Close
# 0       2/2/04   50.099998   50.570000
# 1       2/3/04   50.549999   50.889999
# 2       2/4/04   50.779999   50.930000
# 3       2/5/04   50.930000   50.660000
# 4       2/6/04   50.669998   50.980000
# ...        ...         ...         ...
# 4506  12/23/21  264.000000  264.820007
# 4507  12/27/21  265.350006  266.679993
# 4508  12/28/21  266.809998  265.609985
# 4509  12/29/21  265.540009  266.609985
# 4510  12/30/21  267.309998  267.510010
#
# [4511 rows x 3 columns]

# %%
df2["Date"] = pd.to_datetime(df2["Date"])
df2 = df2.set_index("Date")
df2
# Out:
#                   Open       Close
# Date
# 2004-02-02   50.099998   50.570000
# 2004-02-03   50.549999   50.889999
# 2004-02-04   50.779999   50.930000
# 2004-02-05   50.930000   50.660000
# 2004-02-06   50.669998   50.980000
# ...                ...         ...
# 2021-12-23  264.000000  264.820007
# 2021-12-27  265.350006  266.679993
# 2021-12-28  266.809998  265.609985
# 2021-12-29  265.540009  266.609985
# 2021-12-30  267.309998  267.510010
#
# [4511 rows x 2 columns]

# %%
from matplotlib import style

axis = df2.plot(figsize=(18,5))
axis.set_title("Stock Price by Date (2004-2021)")
axis.set_ylabel("Stock Price ($USD)")
axis.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
vde_df = vde_df.loc[:,["Date","Open","Close"]]

# %%
df = vde_df.reset_index(drop=True)
df
# Out:
#           Date        Open       Close
# 0       1/3/11  100.800003  100.599998
# 1       1/4/11  101.300003   99.839996
# 2       1/5/11   99.480003  100.180000
# 3       1/6/11  100.550003   99.379997
# 4       1/7/11   99.389999  100.000000
# ...        ...         ...         ...
# 2763  12/23/21   77.279999   76.930000
# 2764  12/27/21   76.760002   78.739998
# 2765  12/28/21   78.930000   78.559998
# 2766  12/29/21   78.419998   78.080002
# 2767  12/30/21   78.110001   77.379997
#
# [2768 rows x 3 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.set_index("Date")
df
# Out:
#                   Open       Close
# Date
# 2011-01-03  100.800003  100.599998
# 2011-01-04  101.300003   99.839996
# 2011-01-05   99.480003  100.180000
# 2011-01-06  100.550003   99.379997
# 2011-01-07   99.389999  100.000000
# ...                ...         ...
# 2021-12-23   77.279999   76.930000
# 2021-12-27   76.760002   78.739998
# 2021-12-28   78.930000   78.559998
# 2021-12-29   78.419998   78.080002
# 2021-12-30   78.110001   77.379997
#
# [2768 rows x 2 columns]

# %%
df.dtypes
# Out:
# Open     float64
# Close    float64
# dtype: object

# %%
from matplotlib import style

axis = df.plot(figsize=(18,5))
axis.set_title("Stock Price by Date (2004-2021)")
axis.set_ylabel("Stock Price ($USD)")
axis.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
spy_df
# Out:
#         id      Date        Open        High         Low       Close  \
# 0        1    1/2/01  132.000000  132.156250  127.562500  128.812500
# 1        2    1/3/01  128.312500  136.000000  127.656250  135.000000
# 2        3    1/4/01  134.937500  135.468750  133.000000  133.546875
# 3        4    1/5/01  133.468750  133.625000  129.187500  129.187500
# 4        5    1/8/01  129.875000  130.187500  127.687500  130.187500
# ...    ...       ...         ...         ...         ...         ...
# 5278  5279  12/23/21  468.750000  472.190002  468.640015  470.600006
# 5279  5280  12/27/21  472.059998  477.309998  472.010010  477.260010
# 5280  5281  12/28/21  477.720001  478.809998  476.059998  476.869995
# 5281  5282  12/29/21  476.980011  478.559998  475.920013  477.480011
# 5282  5283  12/30/21  477.929993  479.000000  475.670013  476.160004
#
#        Adj Close    Volume
# 0      85.693497   8737500
# 1      89.809753  19431600
# 2      88.843063   9219000
# ...

# %%
df1 = spy_df.loc[:,["Open", "High", "Low", "Close"]]
df1
# Out:
#             Open        High         Low       Close
# 0     132.000000  132.156250  127.562500  128.812500
# 1     128.312500  136.000000  127.656250  135.000000
# 2     134.937500  135.468750  133.000000  133.546875
# 3     133.468750  133.625000  129.187500  129.187500
# 4     129.875000  130.187500  127.687500  130.187500
# ...          ...         ...         ...         ...
# 5278  468.750000  472.190002  468.640015  470.600006
# 5279  472.059998  477.309998  472.010010  477.260010
# 5280  477.720001  478.809998  476.059998  476.869995
# 5281  476.980011  478.559998  475.920013  477.480011
# 5282  477.929993  479.000000  475.670013  476.160004
#
# [5283 rows x 4 columns]

# %%
X = df1.drop(columns='Close')
y = df1[["Close"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
y_train.dtypes
# Out:
# Close    float64
# dtype: object

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction_close = regr.predict([[126.709999, 127.599998, 125.699997]])
# Out:
# /Users/bryant/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction_close
# Out:
# array([[126.6782278]])

# %%
# Configure settings for RDS
mode = "append"
jdbc_url="jdbc:postgresql://group2.cnrbmfiq1oej.us-east-1.rds.amazonaws.com/group2"
config = {"user":"postgres", 
          "password": "Password", 
          "driver":"org.postgresql.Driver"}

# %%
# create enginge instance to connect to postgresDB to retrieve mastercard data
engine = create_engine("postgresql://postgres:Postgres123!:5432/Group2", echo = True)
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 # create enginge instance to connect to postgresDB to retrieve mastercard data
# ----> 2 engine = create_engine("postgresql://postgres:Postgres123!:5432/Group2", echo = True)
#       3 connection = engine.connect()
#
# NameError: name 'create_engine' is not defined

# %%
# retrieve tables from postgres connection
inspector = inspect(engine)
inspector.get_vde_all()

# Query ALL Records in the the Database
df = pd.read_sql("SELECT * FROM vde_all", connection)
df.head()
